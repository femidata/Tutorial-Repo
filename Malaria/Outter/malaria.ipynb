# %% [markdown]
# # Importing data Into a Pandas DataFrame - How hard can it be?

# %% [markdown]
# To work with data in Pandas, you need to import a dataset. As easy as importing a dataset into a dataframe may sound, i want you to understand that i was stuck in a data import loop for almost two weeks, when i started learning pandas
#
# There are thousands of tutorials
# This article will explain the different ways a dataset can be imported into a dataframe.

# %% [markdown]
# ## Firstly, let us import the pandas library as pd

# %%
# Import the pandas Library
import pandas as pd

# %% [markdown]
# While several data type e.g. excel file, json, html, etc.. can be imported, this article will concentrate on importing a CSV file. The link below is the link that shows the location of the dataset we will be using in this article.
#
# Dataset location on my PC: C:\Users\Femi Odugbesan\Desktop\Malaria\Outter\malaria.csv

# %% [markdown]
# ## Same Folder Import Method
#
# The easiest way to import a data is to call the dataset name directly as seen in the code below, provided the notebook and dataset are in the same folder

# %%
df = pd.read_csv('malaria.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-11-edcfafc95038> in <module>
# ----> 1 df = pd.read_csv('malaria.csv')
#       2 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
# ...

# %% [markdown]
# ## Inner Folder Import Method

# %%
# Read the folder that is contained in the same directory as the jupyter noteboke file
df = pd.read_csv('inner/malaria.csv')
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,5,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  CME_ARR_10T19: Annual Rate of Reduction in Mor...  _T: Total
# 1  CME_ARR_SBR: Annual rate of reduction in still...  _T: Total
# ...

# %% [markdown]
# ## Previous Folder Import Method

# %%
# This method shows how to read a file into a dataframe contained in a previous folder

df = pd.read_csv('../malaria.csv')
df.head()

# %% [markdown]
# ## Full Directory Import Method
#
# Below is the method showing how to import a dataset using the full data directory

# %%
#This code will result an error

df = pd.read_csv('C:\Users\Femi Odugbesan\Desktop\Malaria\Outter\malaria.csv')
df.head()
# Out:
#   File "<ipython-input-6-5155fba88019>", line 3
#     df = pd.read_csv('C:\Users\Femi Odugbesan\Desktop\Malaria\Outter\malaria.csv')
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ## The correct ways to use the full directory methods

# %%
# The error above can easily be solved addition an additional backslash for everywhere there is one
df = pd.read_csv('C:\\Users\\Femi Odugbesan\\Desktop\\Malaria\\Outter\\malaria.csv')
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,5,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  CME_ARR_10T19: Annual Rate of Reduction in Mor...  _T: Total
# 1  CME_ARR_SBR: Annual rate of reduction in still...  _T: Total
# ...

# %%
# Another easy way is to replace every backslash with a forward slash

df = pd.read_csv('C:/Users/Femi Odugbesan/Desktop/Malaria/Outter/malaria.csv')
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,5,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  CME_ARR_10T19: Annual Rate of Reduction in Mor...  _T: Total
# 1  CME_ARR_SBR: Annual rate of reduction in still...  _T: Total
# ...

# %%
#Place a "r" before the filepath quote

df = pd.read_csv(r'C:\Users\Femi Odugbesan\Desktop\Malaria\malaria.csv')
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,5,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  CME_ARR_10T19: Annual Rate of Reduction in Mor...  _T: Total
# 1  CME_ARR_SBR: Annual rate of reduction in still...  _T: Total
# ...
